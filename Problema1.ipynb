# %% [markdown]
# # Problema 1: Venda de Vinhos

# %% [markdown]
# Velasquez possui uma loja de vinhos e, ao longo dos anos, guardou dados de seus clientes e um histórico de compras. Velasquez quer personalizar o atendimento e contratou você para desenvolver um software que:
#
# * 1 - Liste os clientes ordenados pelo maior valor total em compras.
# * 2 - Mostre o cliente com maior compra única no último ano (2016).
# * 3 - Liste os clientes mais fiéis.
# * 4 - Recomende um vinho para um determinado cliente a partir do histórico de compras.
#
#
# Para criar esse software o neto do Velasquez (o Velasquinho) disponibilizou uma API com cadastro de clientes ( http://www.mocky.io/v2/598b16291100004705515ec5 ) e histórico de compras ( http://www.mocky.io/v2/598b16861100004905515ec7 ).

# %%
import json, requests
response = requests.get("http://www.mocky.io/v2/598b16861100004905515ec7")
print(response.status_code)#status_code 200, ok
# Out:
# 200

# %%
print(response.content)
# Out:
# b'    [\n        {\n            "codigo": "3fde36a6-c9a1-4d27-9f0f-7c12ab0d1cdd",\n            "data": "19-02-2016",\n            "cliente": "000.000.000.01",\n            "itens": [\n                {\n                    "produto": "Casa Silva Reserva",\n                    "variedade": "Cabernet Sauvignon",\n                    "pais": "Chile",\n                    "categoria": "Tinto",\n                    "safra": "2014",\n                    "preco": 79\n                },\n                {\n                    "produto": "Casa Silva Reserva",\n                    "variedade": "Carm\xc3\xa9n\xc3\xa8re",\n                    "pais": "Chile",\n                    "categoria": "Tinto",\n                    "safra": "2014",\n                    "preco": 79\n                }\n            ],\n            "valorTotal": 158\n        },\n        {\n            "codigo": "4a7c9be2-5231-4dff-b8e7-9a639286726e",\n            "data": "22-10-2015",\n            "cliente": "0000.000.000.02"
# ...

# %%
conteudo = json.loads(response.content)
type(conteudo)#tipo lista, com vários dicionários
# Out:
# list

# %%
conteudo[0]
# Out:
# {'codigo': '3fde36a6-c9a1-4d27-9f0f-7c12ab0d1cdd',
#  'data': '19-02-2016',
#  'cliente': '000.000.000.01',
#  'itens': [{'produto': 'Casa Silva Reserva',
#    'variedade': 'Cabernet Sauvignon',
#    'pais': 'Chile',
#    'categoria': 'Tinto',
#    'safra': '2014',
#    'preco': 79},
#   {'produto': 'Casa Silva Reserva',
#    'variedade': 'Carménère',
#    'pais': 'Chile',
#    'categoria': 'Tinto',
#    'safra': '2014',
#    'preco': 79}],
#  'valorTotal': 158}

# %%
print(conteudo[0]['cliente'])#assim eu consigo pegar o cliente
# Out:
# 000.000.000.01

# %%
len(conteudo)#portanto há 50 registros em conteudo
# Out:
# 50

# %%
#ordenando os clientes pelo valorTotal

lista_ordenada = sorted(conteudo, key=lambda chave: chave['valorTotal'])
lista_ordenada
# Out:
# [{'codigo': 'fc41d3a1-1eef-49c5-905c-d19e747eb6c5',
#   'data': '06-08-2015',
#   'cliente': '0000.000.000.04',
#   'itens': [{'produto': 'Casa Valduga Raízes',
#     'variedade': 'Chardonnay',
#     'pais': 'Brasil',
#     'categoria': 'Branco',
#     'safra': '2013',
#     'preco': 55}],
#   'valorTotal': 55},
#  {'codigo': '6f0bee3e-4988-4e23-83f6-c28af6ba0464',
#   'data': '15-08-2016',
#   'cliente': '0000.000.000.03',
#   'itens': [{'produto': 'Casa Silva Reserva',
#     'variedade': 'Sauvignon Blanc',
#     'pais': 'Chile',
#     'categoria': 'Branco',
#     'safra': '2015',
#     'preco': 79}],
#   'valorTotal': 79},
#  {'codigo': '517ec2b6-1d3d-48a1-9ed4-a51e20ce18df',
#   'data': '15-11-2016',
#   'cliente': '0000.000.000.09',
#   'itens': [{'codigo': 'e9eee4af-13d0-4da1-9a91-36b100e1c98e',
#     'produto': 'Casa Valduga Raízes',
#     'variedade': 'Merlot',
#     'pais': 'Brasil',
#     'categoria': 'Tinto',
#     'safra': '2013',
#     'preco': 55},
# ...

# %%
lista_ordenada_decrescente = sorted(conteudo, key=lambda chave: -chave['valorTotal'])
lista_ordenada_decrescente
#primeiro item resolvido
# Out:
# [{'codigo': '38ef8665-61df-4402-94f8-3c9b28ab7123',
#   'data': '17-09-2016',
#   'cliente': '0000.000.000.06',
#   'itens': [{'codigo': '449cb4e2-67d1-4087-9192-4ac6bd018727',
#     'produto': 'Saint Emilion Château La Clide Gran Cru',
#     'variedade': 'Merlot',
#     'pais': 'França',
#     'categoria': 'Tinto',
#     'safra': '2009',
#     'preco': 298},
#    {'codigo': '449cb4e2-67d1-4087-9192-4ac6bd018727',
#     'produto': 'Saint Emilion Château La Clide Gran Cru',
#     'variedade': 'Merlot',
#     'pais': 'França',
#     'categoria': 'Tinto',
#     'safra': '2009',
#     'preco': 298},
#    {'produto': 'Punto Final',
#     'variedade': 'Sauvignon Blanc',
#     'pais': 'Argentina',
#     'categoria': 'Branco',
#     'safra': '2015',
#     'preco': 59.9}],
#   'valorTotal': 655.9},
#  {'codigo': 'f838c843-9eab-4b4d-bf7e-b2d2f472dfb2',
#   'data': '01-06-2016',
#   'cliente': '0000.000.000.05',
#   'itens': [{'produto': 'Casa Valduga Raízes',
#     'variedade': 'Chardonnay',
# ...

# %%
lista_2016 = []
for dados in lista_ordenada_decrescente:
    if dados['data'][-4:] == '2016':
        lista_2016.append(dados)

# %%
len(lista_2016)
#38 itens são de 2016
# Out:
# 38

# %%
lista_2016[0]['itens'][0]#dict
lista_2016[0]['itens']#list
# Out:
# [{'codigo': '449cb4e2-67d1-4087-9192-4ac6bd018727',
#   'produto': 'Saint Emilion Château La Clide Gran Cru',
#   'variedade': 'Merlot',
#   'pais': 'França',
#   'categoria': 'Tinto',
#   'safra': '2009',
#   'preco': 298},
#  {'codigo': '449cb4e2-67d1-4087-9192-4ac6bd018727',
#   'produto': 'Saint Emilion Château La Clide Gran Cru',
#   'variedade': 'Merlot',
#   'pais': 'França',
#   'categoria': 'Tinto',
#   'safra': '2009',
#   'preco': 298},
#  {'produto': 'Punto Final',
#   'variedade': 'Sauvignon Blanc',
#   'pais': 'Argentina',
#   'categoria': 'Branco',
#   'safra': '2015',
#   'preco': 59.9}]

# %%
lista_2016[0]['itens'][0]['preco']
# Out:
# 298

# %%
#maior valor total de 2016, e cliente, pois esta lista foi obtida da lista ordenada 
#decrescente
lista_2016[0]['valorTotal']
# Out:
# 655.9

# %%
#menor valor
lista_2016[-1]['valorTotal']
# Out:
# 79

# %%
#logo, o cliente e sua compra são:
lista_2016[0]['cliente'], lista_2016[0]['valorTotal']
# Out:
# ('0000.000.000.06', 655.9)

# %%
#buscando o nome do cliente
response_cliente = requests.get("http://www.mocky.io/v2/598b16291100004705515ec5")
print(response_cliente.status_code)
# Out:
# 200

# %%
cliente = json.loads(response_cliente.content)
type(cliente)
# Out:
# list

# %%
cliente
# Out:
# [{'id': 1, 'nome': 'Vinicius', 'cpf': '000.000.000-01'},
#  {'id': 2, 'nome': 'Marcos', 'cpf': '000.000.000-02'},
#  {'id': 3, 'nome': 'Joel', 'cpf': '000.000.000-03'},
#  {'id': 4, 'nome': 'Gustavo', 'cpf': '000.000.000-04'},
#  {'id': 5, 'nome': 'Raquel', 'cpf': '000.000.000-05'},
#  {'id': 6, 'nome': 'Pamela', 'cpf': '000.000.000-06'},
#  {'id': 7, 'nome': 'Bruno', 'cpf': '000.000.000-07'},
#  {'id': 8, 'nome': 'Jonathan', 'cpf': '000.000.000-08'},
#  {'id': 9, 'nome': 'Matheus', 'cpf': '000.000.000-09'},
#  {'id': 10, 'nome': 'Rafael', 'cpf': '000.000.000-10'}]

# %%
print(cliente[0]['nome'])
# Out:
# Vinicius

# %%
for i in range(len(cliente)):
    print(cliente[i]['nome'])
#os nomes dos 10 clientes
# Out:
# Vinicius
# Marcos
# Joel
# Gustavo
# Raquel
# Pamela
# Bruno
# Jonathan
# Matheus
# Rafael

# %%
for i in range(len(cliente)):
    if str(cliente[i]['cpf']) == '0000.000.000.06':
        print(cliente[i]['nome'])
    print(str(cliente[i]['cpf']))
# Out:
# 000.000.000-01
# 000.000.000-02
# 000.000.000-03
# 000.000.000-04
# 000.000.000-05
# 000.000.000-06
# 000.000.000-07
# 000.000.000-08
# 000.000.000-09
# 000.000.000-10

# %%
for i in range(len(cliente)):
    if str(cliente[i]['cpf']) == lista_2016[0]['cliente'].replace(lista_2016[0]['cliente'][-3], ','):
        print(cliente[i]['nome'])

# %%
for i in range(len(cliente)):
    if cliente[i]['cpf'].replace('-', '.') == lista_2016[0]['cliente']:
        print(cliente[i]['nome'])

# %%
cliente[2]['cpf'].replace('-', '.')
# Out:
# '000.000.000.03'

# %%
lista_2016[0]['cliente']
# Out:
# '0000.000.000.06'

# %%
#percebido uma correção a ser feita: todos os clientes da api de produtos possuem 1um 
#0 a mais, do que seu correspondente na api de clientes

# %%
for i in range(len(cliente)):
    if '0' + cliente[i]['cpf'].replace('-', '.') == lista_2016[0]['cliente']:
        print(cliente[i]['nome'])
# Out:
# Pamela

# %%
lista_ordenada_decrescente[0]['cliente']
# Out:
# '0000.000.000.06'

# %%
#lista dos nomes dos clientes:
nomes = []
for i in range(len(cliente)):
    nomes.append(cliente[i]['nome'])
len(nomes)
# Out:
# 10

# %%
lista_ordenada_decrescente.count('Vinicius')
# Out:
# 0

# %%
for i in range(len(lista_ordenada_decrescente)):
    print(lista_ordenada_decrescente[i]['cliente'])
# Out:
#   File "<ipython-input-90-832a427e6bf0>", line 2
#     #print(lista_ordenada_decrescente[i]['cliente'])
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in range(len(cliente)):
    print('0' + cliente[i]['cpf'].replace('-', '.'))
# Out:
# 0000.000.000.01
# 0000.000.000.02
# 0000.000.000.03
# 0000.000.000.04
# 0000.000.000.05
# 0000.000.000.06
# 0000.000.000.07
# 0000.000.000.08
# 0000.000.000.09
# 0000.000.000.10

# %%
for i in range(len(cliente)):
    print(lista_ordenada_decrescente[i].count('0' + cliente[i]['cpf'].replace('-', '.')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-944c87ea6a48> in <module>
#       1 for i in range(len(cliente)):
# ----> 2     print(lista_ordenada_decrescente[i].count('0' + cliente[i]['cpf'].replace('-', '.')))
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
from collections import Counter
Counter(lista_ordenada_decrescente).most_common(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-89db1ce838f2> in <module>
#       1 from collections import Counter
# ----> 2 Counter(lista_ordenada_decrescente).most_common(2)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/collections/__init__.py in __init__(*args, **kwds)
#     533             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     534         super(Counter, self).__init__()
# --> 535         self.update(*args, **kwds)
#     536
#     537     def __missing__(self, key):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/collections/__init__.py in update(*args, **kwds)
#     620                     super(Counter, self).update(iterable) # fast path when counter is empty
#     621             else:
# --> 622                 _count_elements(self, iterable)
#     623         if kwds:
#     624             self.update(kwds)
#
# ...

# %%
lista_ordenada_decrescente[0:-1]
nomes
# Out:
# ['Vinicius',
#  'Marcos',
#  'Joel',
#  'Gustavo',
#  'Raquel',
#  'Pamela',
#  'Bruno',
#  'Jonathan',
#  'Matheus',
#  'Rafael']

# %%
nomes_historico = []
for nome in range(len(lista_ordenada_decrescente)):
    #print(lista_ordenada_decrescente[nome]['cliente'])
    nomes_historico.append(lista_ordenada_decrescente[nome]['cliente'])

# %%
#desta forma eu tenho apenas uma lista com a repeticao dos clientes
len(nomes_historico)
# Out:
# 50

# %%
nomes_historico
# Out:
# ['0000.000.000.06',
#  '0000.000.000.05',
#  '0000.000.000.03',
#  '0000.000.000.06',
#  '0000.000.000.08',
#  '0000.000.000.01',
#  '0000.000.000.05',
#  '0000.000.000.05',
#  '0000.000.000.07',
#  '0000.000.000.08',
#  '0000.000.000.09',
#  '0000.000.000.06',
#  '0000.000.000.03',
#  '0000.000.000.10',
#  '0000.000.000.02',
#  '0000.000.000.02',
#  '0000.000.000.03',
#  '0000.000.000.07',
#  '0000.000.000.04',
#  '0000.000.000.07',
#  '0000.000.000.04',
#  '0000.000.000.08',
#  '0000.000.000.04',
#  '0000.000.000.10',
#  '0000.000.000.08',
#  '0000.000.000.09',
#  '0000.000.000.07',
#  '0000.000.000.04',
#  '0000.000.000.08',
#  '0000.000.000.04',
#  '0000.000.000.03',
#  '0000.000.000.02',
#  '0000.000.000.05',
#  '0000.000.000.05',
#  '0000.000.000.08',
#  '0000.000.000.07',
#  '0000.000.000.03',
#  '0000.000.000.08',
#  '0000.000.000.08',
#  '0000.000.000.08',
#  '0000.000.000.04',
#  '0000.000.000.10',
#  '0000.000.000.06',
#  '0000.000.000.02',
#  '0000.000.000.08',
# ...

# %%
#consertando o objeto i = -5
nomes_historico[-5] = '0' + nomes_historico[-5]
#e retornando suas frequências
for i in range(len(cliente)):
    print(nomes_historico.count('0' + cliente[i]['cpf'].replace('-', '.')))
# Out:
# 2
# 4
# 6
# 8
# 5
# 4
# 5
# 10
# 3
# 3

# %%
#fazendo uma lista das frequências
freq_nomes = []
for i in range(len(cliente)):
    freq_nomes.append(nomes_historico.count('0' + cliente[i]['cpf'].replace('-', '.')))

# %%
#testando se o número total é igual a 50
sum(freq_nomes) == 50
# Out:
# True

# %%
#testando se o número de valores é 10
len(freq_nomes) == 10
# Out:
# True

# %%
#Como a ordem da lista de frequencias segue a ordem da lista nomes
fidelidade = {'nome', 'frequencia'}
for nome in range(len(nomes)):
    fidelidade['nome'].get(nomes[nome])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-6b9bf8286ce7> in <module>
#       2 fidelidade = {'nome', 'frequencia'}
#       3 for nome in range(len(nomes)):
# ----> 4     fidelidade['nome'].get(nomes[nome])
#
# TypeError: 'set' object is not subscriptable

# %%
nomes
# Out:
# ['Vinicius',
#  'Marcos',
#  'Joel',
#  'Gustavo',
#  'Raquel',
#  'Pamela',
#  'Bruno',
#  'Jonathan',
#  'Matheus',
#  'Rafael']

# %%
nomes
freq_nomes
nomes_freq = dict(zip(nomes, freq_nomes))

# %%
#assim eu tenho um dicionario da fidelidade dos clientes
nomes_freq
# Out:
# {'Vinicius': 2,
#  'Marcos': 4,
#  'Joel': 6,
#  'Gustavo': 8,
#  'Raquel': 5,
#  'Pamela': 4,
#  'Bruno': 5,
#  'Jonathan': 10,
#  'Matheus': 3,
#  'Rafael': 3}

# %%
#e o mais fiel
import operator
max(nomes_freq.items(), key=operator.itemgetter(1))[0]
# Out:
# 'Jonathan'

# %%
#o mais fiel e menos fiel otimizado
max(nomes_freq, key=nomes_freq.get), min(nomes_freq, key=nomes_freq.get)
# Out:
# ('Jonathan', 'Vinicius')

# %%
objeto = list((conteudo[0].values()))[3]

# %%
objeto
# Out:
# [{'produto': 'Casa Silva Reserva',
#   'variedade': 'Cabernet Sauvignon',
#   'pais': 'Chile',
#   'categoria': 'Tinto',
#   'safra': '2014',
#   'preco': 79},
#  {'produto': 'Casa Silva Reserva',
#   'variedade': 'Carménère',
#   'pais': 'Chile',
#   'categoria': 'Tinto',
#   'safra': '2014',
#   'preco': 79}]

# %%
objeto[0]['produto'], len(objeto)
# Out:
# ('Casa Silva Reserva', 2)

# %%
vinhos = []#testando para o cliente 000.000.000.01
for i in range(len(conteudo)):
    if conteudo[i]['cliente'] == '0000.000.000.02':
        vinhos.append(conteudo[i]['itens'])

# %%
vinhos['produtos']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-253-b5375ff98a18> in <module>
# ----> 1 vinhos['produtos']
#
# TypeError: list indices must be integers or slices, not str

# %%
conteudo
# Out:
# [{'codigo': '3fde36a6-c9a1-4d27-9f0f-7c12ab0d1cdd',
#   'data': '19-02-2016',
#   'cliente': '000.000.000.01',
#   'itens': [{'produto': 'Casa Silva Reserva',
#     'variedade': 'Cabernet Sauvignon',
#     'pais': 'Chile',
#     'categoria': 'Tinto',
#     'safra': '2014',
#     'preco': 79},
#    {'produto': 'Casa Silva Reserva',
#     'variedade': 'Carménère',
#     'pais': 'Chile',
#     'categoria': 'Tinto',
#     'safra': '2014',
#     'preco': 79}],
#   'valorTotal': 158},
#  {'codigo': '4a7c9be2-5231-4dff-b8e7-9a639286726e',
#   'data': '22-10-2015',
#   'cliente': '0000.000.000.02',
#   'itens': [{'produto': 'Casa Silva Reserva',
#     'variedade': 'Chardonnay',
#     'pais': 'Chile',
#     'categoria': 'Branco',
#     'safra': '2016',
#     'preco': 79},
#    {'produto': 'Casa Silva Reserva',
#     'variedade': 'Sauvignon Blanc',
#     'pais': 'Chile',
#     'categoria': 'Branco',
#     'safra': '2015',
#     'preco': 79},
#    {'produto': 'Casa Silva Gran Reserva',
# ...

# %%
brinde = []
for i in range(len(conteudo)):
    if conteudo[i]['cliente'] == '0000.000.000.02':
        brinde.append(conteudo[i]['itens'])

# %%
escolhido = []
brinde
for lista1 in brinde:
    print('lista1')
    for lista2 in lista1:
        #print(lista2['produto'])
        escolhido.append(lista2['produto'])
# Out:
# lista1
# Casa Silva Reserva
# Casa Silva Reserva
# Casa Silva Gran Reserva
# lista1
# Casa Silva Gran Reserva
# Casa Valduga Villa Lobos
# Finca La Emperatriz Crianza
# lista1
# Wente Reliz Creek Pinot Noir
# Casa Valduga Raízes
# Casa Valduga Gran Reserva
# lista1
# Casa Silva Reserva
# Casa Valduga Raízes
# Casa Valduga Raízes

# %%
brinde
# Out:
# [[{'produto': 'Casa Silva Reserva',
#    'variedade': 'Chardonnay',
#    'pais': 'Chile',
#    'categoria': 'Branco',
#    'safra': '2016',
#    'preco': 79},
#   {'produto': 'Casa Silva Reserva',
#    'variedade': 'Sauvignon Blanc',
#    'pais': 'Chile',
#    'categoria': 'Branco',
#    'safra': '2015',
#    'preco': 79},
#   {'produto': 'Casa Silva Gran Reserva',
#    'variedade': 'Petit Verdot',
#    'pais': 'Chile',
#    'categoria': 'Tinto',
#    'safra': '2009',
#    'preco': 120}],
#  [{'produto': 'Casa Silva Gran Reserva',
#    'variedade': 'Petit Verdot',
#    'pais': 'Chile',
#    'categoria': 'Tinto',
#    'safra': '2009',
#    'preco': 120},
#   {'produto': 'Casa Valduga Villa Lobos',
#    'variedade': 'Cabernet Sauvignon',
#    'pais': 'Brasil',
#    'categoria': 'Tinto',
#    'safra': '2007',
#    'preco': 140},
#   {'produto': 'Finca La Emperatriz Crianza',
#    'variedade': 'Tempranillo',
#    'pais': 'Espanha',
#    'categoria': 'Tinto',
#    'safra': '2008',
# ...

# %%
escolhido
# Out:
# ['Casa Silva Reserva',
#  'Casa Silva Reserva',
#  'Casa Silva Gran Reserva',
#  'Casa Silva Gran Reserva',
#  'Casa Valduga Villa Lobos',
#  'Finca La Emperatriz Crianza',
#  'Wente Reliz Creek Pinot Noir',
#  'Casa Valduga Raízes',
#  'Casa Valduga Gran Reserva',
#  'Casa Silva Reserva',
#  'Casa Valduga Raízes',
#  'Casa Valduga Raízes']

# %%
freq_escolhido = []
for i in range(len(escolhido)):
    freq_escolhido.append(escolhido.count(escolhido[i]))

# %%
freq_escolhido
# Out:
# [3, 3, 2, 2, 1, 1, 1, 3, 1, 3, 3, 3]

# %%
produto_freq = dict(zip(escolhido, freq_escolhido))
produto_freq
# Out:
# {'Casa Silva Reserva': 3,
#  'Casa Silva Gran Reserva': 2,
#  'Casa Valduga Villa Lobos': 1,
#  'Finca La Emperatriz Crianza': 1,
#  'Wente Reliz Creek Pinot Noir': 1,
#  'Casa Valduga Raízes': 3,
#  'Casa Valduga Gran Reserva': 1}

# %%
#retornando o escolhido
max(produto_freq, key=produto_freq.get)
# Out:
# 'Casa Silva Reserva'

# %%
#e para a seleção de um vinho a partir do histórico do cliente
api_historico = 'http://www.mocky.io/v2/598b16861100004905515ec7'
api_cliente = 'http://www.mocky.io/v2/598b16291100004705515ec5'

def seleciona_vinho(api_historico,cpf_cliente):
    conteudo = conecta_api(api_historico)
    brinde = []
    for i in range(len(conteudo)):
        if conteudo[i]['cliente'] == cpf_cliente:
            brinde.append(conteudo[i]['itens'])

    escolhido = []
    for lista1 in brinde:
        for lista2 in lista1:
            #print(lista2['produto'])
            escolhido.append(lista2['produto'])
    freq_escolhido = []
    for i in range(len(escolhido)):
        freq_escolhido.append(escolhido.count(escolhido[i]))
    produto_freq = dict(zip(escolhido, freq_escolhido))
    return(max(produto_freq, key=produto_freq.get))

seleciona_vinho('http://www.mocky.io/v2/598b16861100004905515ec7', '0000.000.000.02')

# %%
#gerar um código que converta o cpf no nome do cliente
response_cliente = requests.get("http://www.mocky.io/v2/598b16291100004705515ec5")
cliente = json.loads(response_cliente.content)
dicionario = {}
for i in range(len(cliente)):
    dicionario.update({cliente[i]['nome']:cliente[i]['cpf']})

# %%
"""O programa deve fazer o caminho inverso, pois na api de histórico consta somente 
os cpfs dos clientes"""
dicionario
# Out:
# {'Vinicius': '000.000.000-01',
#  'Marcos': '000.000.000-02',
#  'Joel': '000.000.000-03',
#  'Gustavo': '000.000.000-04',
#  'Raquel': '000.000.000-05',
#  'Pamela': '000.000.000-06',
#  'Bruno': '000.000.000-07',
#  'Jonathan': '000.000.000-08',
#  'Matheus': '000.000.000-09',
#  'Rafael': '000.000.000-10'}

# %%
for key in dicionario.keys():
    print(key, dicionario[key])
# Out:
# Vinicius 000.000.000-01
# Marcos 000.000.000-02
# Joel 000.000.000-03
# Gustavo 000.000.000-04
# Raquel 000.000.000-05
# Pamela 000.000.000-06
# Bruno 000.000.000-07
# Jonathan 000.000.000-08
# Matheus 000.000.000-09
# Rafael 000.000.000-10
